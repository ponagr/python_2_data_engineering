# %% [markdown]
# We will be working with raw data from Open Stockholm and Open Weather Map APIs. Both APIs require API key for accessing data. Therefore, before working with tasks below, you need to obtain API keys for both data sources and understand how to work with these secrets securely.
#
# API key for weather data
# Create an account at Open Weather Map homepage and obtain API key under your account.
#
# API key for Stockholm parking data
# Obtain an API key from this link from Stockholm city- Open Stockholm homepage.
#
# Working with secrets
# When making a GET request to both APIs, you need to provide the API endpoint (URL) together with the API keys for authentication. However, you should not expose your API keys in your python scripts. Instead, you can make use of .env file. Make sure that this file IS NOT TRACKED by git. Check out this reference to understand how to use .env file to work with secrets.

# %%
import pandas as pd
import os
from dotenv import load_dotenv
import requests
import json
import dlt
from datetime import datetime
import duckdb



# load_dotenv("openweatherAPI.env")

# API_KEY = os.getenv("API_KEY")
API_KEY = dlt.secrets.get("api_secret_key")
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

citys = ["Stockholm", "London", "Paris", "New York", "Tokyo"]

# %%
def fetch_weather_data(city):
    params = {
        "q":city, 
        "appid":API_KEY, 
        "units": "metric"
    ,}
    
    response = requests.get(BASE_URL, params=params)
    data = response.json() #json.loads(response.content.decode("utf8"))
    
    weather_dict = {
    "city": city,
    "timestamp": datetime.now().isoformat(),
    "temperature": data["main"]["temp"],
    "humidity": data["main"]["humidity"],
    "pressure": data["main"]["pressure"],
    "weather_description": data["weather"][0]["description"],
    "wind_speed": data["wind"]["speed"],
    "cloudiness": data["clouds"]["all"]
    }
    return weather_dict


@dlt.resource(write_disposition="replace")
def append_weather_data():
    for city in citys:
        yield fetch_weather_data(city)


def create_weather_pipeline():
    pipeline = dlt.pipeline(
        pipeline_name="weather_data_pipeline",
        destination=dlt.destinations.duckdb("weather_data.duckdb"),
        dataset_name="staging"
    )
    
    pipeline.run(append_weather_data(), table_name="weather_by_city")
    return pipeline


pipeline = create_weather_pipeline()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\extract\pipe_iterator.py:277, in PipeIterator._get_source_item(self)
#     275 set_current_pipe_name(pipe.name)
# --> 277 pipe_item = next(gen)
#     278 if pipe_item is not None:
#     279     # full pipe item may be returned, this is used by ForkPipe step
#     280     # to redirect execution of an item to another pipe
#     281     # else
#
# Cell In[2], line 27, in append_weather_data()
#      26 for city in citys:
# ---> 27     yield fetch_weather_data(city)
#
# Cell In[2], line 14, in fetch_weather_data(city)
#       9 data = response.json() #json.loads(response.content.decode("utf8"))
#      11 weather_dict = {
#      12 "city": city,
#      13 "timestamp": datetime.now().isoformat(),
# ---> 14 "temperature": data["main"]["temp"],
#      15 "humidity": data["main"]["humidity"],
#      16 "pressure": data["main"]["pressure"],
#      17 "weather_description": data["weather"][0]["description"],
#      18 "wind_speed": data["wind"]["speed"],
#      19 "cloudiness": data["clouds"]["all"]
#      20 }
#      21 return weather_dict
#
# KeyError: 'main'
#
# The above exception was the direct cause of the following exception:
#
# ResourceExtractionError                   Traceback (most recent call last)
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:466, in Pipeline.extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     464         raise SourceExhausted(source.name)
# --> 466     self._extract_source(
#     467         extract_step,
#     468         source,
#     469         max_parallel_items,
#     470         workers,
#     471         refresh=refresh or self.refresh,
#     472     )
#     474 # this will update state version hash so it will not be extracted again by with_state_sync
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:1238, in Pipeline._extract_source(self, extract, source, max_parallel_items, workers, refresh, load_package_state_update)
#    1237 # extract into pipeline schema
# -> 1238 load_id = extract.extract(
#    1239     source, max_parallel_items, workers, load_package_state_update=load_package_state_update
#    1240 )
#    1242 # update live schema but not update the store yet
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\extract\extract.py:435, in Extract.extract(self, source, max_parallel_items, workers, load_package_state_update)
#     433             reset_resource_state(resource.name)
# --> 435 self._extract_single_source(
#     436     load_id,
#     437     source,
#     438     max_parallel_items=max_parallel_items,
#     439     workers=workers,
#     440 )
#     441 commit_load_package_state()
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\extract\extract.py:358, in Extract._extract_single_source(self, load_id, source, max_parallel_items, workers)
#     357 collector.update("Resources", 0, total_gens)
# --> 358 for pipe_item in pipes:
#     359     curr_gens = len(pipes._sources)
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\extract\pipe_iterator.py:162, in PipeIterator.__next__(self)
#     160 if pipe_item is None:
#     161     # if none then take element from the newest source
# --> 162     pipe_item = self._get_source_item()
#     164 if pipe_item is None:
#     165     # Wait for some time for futures to resolve
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\extract\pipe_iterator.py:307, in PipeIterator._get_source_item(self)
#     306 except Exception as ex:
# --> 307     raise ResourceExtractionError(pipe.name, gen, str(ex), "generator") from ex
#
# ResourceExtractionError: In processing pipe append_weather_data: extraction of resource append_weather_data in generator append_weather_data caused an exception: 'main'
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# Cell In[2], line 41
#      37     pipeline.run(append_weather_data(), table_name="weather_by_city")
#      38     return pipeline
# ---> 41 pipeline = create_weather_pipeline()
#
# Cell In[2], line 37, in create_weather_pipeline()
#      30 def create_weather_pipeline():
#      31     pipeline = dlt.pipeline(
#      32         pipeline_name="weather_data_pipeline",
#      33         destination=dlt.destinations.duckdb("weather_data.duckdb"),
#      34         dataset_name="staging"
#      35     )
# ---> 37     pipeline.run(append_weather_data(), table_name="weather_by_city")
#      38     return pipeline
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:221, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     218     if trace:
#     219         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 221     step_info = f(self, *args, **kwargs)
#     222     return step_info
#     223 except Exception as ex:
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:270, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     262 @wraps(f)
#     263 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     264     # add section context to the container to be used by all configuration without explicit sections resolution
#     265     with inject_section(
#     266         ConfigSectionContext(
#     267             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     268         )
#     269     ):
# --> 270         return f(self, *args, **kwargs)
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:730, in Pipeline.run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     728 # extract from the source
#     729 if data is not None:
# --> 730     self.extract(
#     731         data,
#     732         table_name=table_name,
#     733         write_disposition=write_disposition,
#     734         columns=columns,
#     735         primary_key=primary_key,
#     736         schema=schema,
#     737         table_format=table_format,
#     738         schema_contract=schema_contract,
#     739         refresh=refresh or self.refresh,
#     740     )
#     741     self.normalize(loader_file_format=loader_file_format)
#     742     return self.load(destination, dataset_name, credentials=credentials)
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:221, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     218     if trace:
#     219         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 221     step_info = f(self, *args, **kwargs)
#     222     return step_info
#     223 except Exception as ex:
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:175, in with_schemas_sync.<locals>._wrap(self, *args, **kwargs)
#     173     self._schema_storage.commit_live_schema(name)
#     174 try:
# --> 175     rv = f(self, *args, **kwargs)
#     176 except Exception:
#     177     # because we committed live schema before calling f, we may safely
#     178     # drop all changes in live schemas
#     179     for name in list(self._schema_storage.live_schemas.keys()):
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:161, in with_state_sync.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     159 should_extract_state = may_extract_state and self.config.restore_from_destination
#     160 with self.managed_state(extract_state=should_extract_state):
# --> 161     return f(self, *args, **kwargs)
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:270, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     262 @wraps(f)
#     263 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     264     # add section context to the container to be used by all configuration without explicit sections resolution
#     265     with inject_section(
#     266         ConfigSectionContext(
#     267             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     268         )
#     269     ):
# --> 270         return f(self, *args, **kwargs)
#
# File c:\Users\organ\Repos\python\python_school_stuff\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:487, in Pipeline.extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     485 step_info = self._get_step_info(extract_step)
#     486 current_load_id = step_info.loads_ids[-1] if len(step_info.loads_ids) > 0 else None
# --> 487 raise PipelineStepFailed(
#     488     self,
#     489     "extract",
#     490     current_load_id,
#     491     exc,
#     492     step_info,
#     493 ) from exc
#
# PipelineStepFailed: Pipeline execution failed at stage extract when processing package 1743686557.0390077 with exception:
#
# <class 'dlt.extract.exceptions.ResourceExtractionError'>
# In processing pipe append_weather_data: extraction of resource append_weather_data in generator append_weather_data caused an exception: 'main'

# %%
with duckdb.connect("weather_data.duckdb") as con:
    result = con.execute("SELECT * FROM staging.weather_by_city").fetchall()
    for row in result:
        print(row)
# Out:
# ('Stockholm', datetime.datetime(2025, 4, 3, 17, 8, 55, 786378, tzinfo=<DstTzInfo 'Europe/Stockholm' CEST+2:00:00 DST>), 19.47, 34, 1020, 'clear sky', 8.23, 0, '1743685735.6656818', 'FZa+Jo76WD+4Zg')
# ('London', datetime.datetime(2025, 4, 3, 17, 8, 55, 885646, tzinfo=<DstTzInfo 'Europe/Stockholm' CEST+2:00:00 DST>), 18.14, 48, 1019, 'few clouds', 4.47, 17, '1743685735.6656818', 'pDh1LU4/SjjL1A')
# ('Paris', datetime.datetime(2025, 4, 3, 17, 8, 55, 983717, tzinfo=<DstTzInfo 'Europe/Stockholm' CEST+2:00:00 DST>), 20.5, 42, 1017, 'clear sky', 7.2, 0, '1743685735.6656818', 'ddESZ9fcbm8xgQ')
# ('New York', datetime.datetime(2025, 4, 3, 17, 8, 56, 83787, tzinfo=<DstTzInfo 'Europe/Stockholm' CEST+2:00:00 DST>), 9.84, 93, 1019, 'mist', 2.24, 100, '1743685735.6656818', 'n+0kNUxrjXwqFQ')
# ('Tokyo', datetime.datetime(2025, 4, 3, 17, 8, 56, 183798, tzinfo=<DstTzInfo 'Europe/Stockholm' CEST+2:00:00 DST>), 7.86, 83, 1014, 'broken clouds', 5.14, 75, '1743685735.6656818', 'TlSq9tMGiVbfrA')

# %%
pipeline.dataset().weather_by_city.df()
# Out:
#         city                        timestamp  temperature  humidity  \
# 0  Stockholm 2025-04-03 11:10:30.376138+00:00        13.76        54
# 1     London 2025-04-03 11:10:30.479370+00:00        13.94        64
# 2      Paris 2025-04-03 11:10:30.597851+00:00        15.26        55
# 3   New York 2025-04-03 11:10:30.704479+00:00         7.32        93
# 4      Tokyo 2025-04-03 11:10:30.822041+00:00         8.48        83
#
#    pressure weather_description  wind_speed  cloudiness       _dlt_load_id  \
# 0      1024           clear sky        5.14           0  1743671430.240295
# 1      1019           clear sky        6.17           2  1743671430.240295
# 2      1017           clear sky        4.63           0  1743671430.240295
# 3      1022     overcast clouds        3.60         100  1743671430.240295
# 4      1014       broken clouds        5.14          75  1743671430.240295
#
#           _dlt_id
# 0  OMr4wxx4GGClXg
# 1  CHoTozDvoM65FA
# 2  QqgY7mQxJLLUTA
# 3  y/PtdTm5eUDF2A
# 4  oAXikjqvTaOa0w
